# %% [markdown]
# # Imports and Config

# %%
import pandas as pd
import seaborn as sns

# %%
sns.set_theme(style="whitegrid")

# %% [markdown]
# # Data

# %%
df_exc = pd.ExcelFile("../data/EI-Stats-Review-ALL-data.xlsx")

# %%
df_exc.sheet_names
# Out:
# ['Contents',
#  'Total Energy Supply (TES) -EJ',
#  'TES by fuel',
#  'TES per Capita',
#  'CO2 from Energy',
#  'Natural Gas Flaring',
#  'CO2 from Flaring',
#  'CO2-Process Emissions, Methane',
#  'CO2e Emissions ',
#  'CCUS Capture Capacity',
#  'Carbon Prices',
#  'Oil - Proved reserves',
#  'Oil - Proved reserves history',
#  'Oil Production - barrels',
#  'Oil Production - tonnes',
#  'Crude+cond production - barrels',
#  'NGLs production - barrels',
#  'Liquids Consumption - barrels',
#  'Oil Consumption - barrels',
#  'Oil Consumption - Tonnes',
#  'Oil Consumption - EJ',
#  'Oil - Regional Consumption',
#  'Spot crude prices',
#  'Oil crude prices since 1861',
#  'Oil refinery - throughput',
#  'Oil refinery - capacity',
#  'Oil - Regional refining margins',
#  'Oil trade movements',
#  'Oil - Inter-area movements',
#  'Oil - Trade movements in 23-24',
#  'Gas - Proved reserves',
#  'Gas - Proved reserves history',
#  'Gas Production - Bcm',
#  'Gas Production - bcf',
# ...

# %%
int_sheets = [
    'CO2 from Energy', 'Electricity Generation - TWh', 'Elec generation by fuel',
     'Oil inputs - Elec generation ', 'Gas inputs - Elec generation', 'Coal inputs - Elec generation ',
     'Other inputs - Elec generation', 'Wind Generation - TWh', 'Solar Generation - TWh',
     'Nuclear Generation - TWh', 'Hydro Generation - TWh'
]

# %%
df_all = pd.read_csv("../data/panel_format.csv")

# %% [markdown]
# # Exploration

# %%
df_all.head()
# Out:
#    Country  Year        pop ISO3166_alpha3  ISO3166_numeric  Region  \
# 0  Algeria  1965  12.365976            DZA             12.0  Africa
# 1  Algeria  1966  12.590069            DZA             12.0  Africa
# 2  Algeria  1967  12.876118            DZA             12.0  Africa
# 3  Algeria  1968  13.172614            DZA             12.0  Africa
# 4  Algeria  1969  13.475960            DZA             12.0  Africa
#
#          SubRegion  OPEC   EU  OECD  ...  ren_power_twh_net  renewables_ej  \
# 0  Northern Africa   1.0  0.0   0.0  ...                  0       0.001440
# 1  Northern Africa   1.0  0.0   0.0  ...                  0       0.001278
# 2  Northern Africa   1.0  0.0   0.0  ...                  0       0.001476
# 3  Northern Africa   1.0  0.0   0.0  ...                  0       0.002027
# 4  Northern Africa   1.0  0.0   0.0  ...                  0       0.001300
#
#    solar_ej  solar_twh  solar_twh_net    tes_ej  tes_gj_pc  wind_ej  wind_twh  \
# ...

# %%
sns.lineplot(data=df_all[df_all['EU']==1.0], x="Year", y="electbyfuel_total", hue="Country")
# Out:
# <Axes: xlabel='Year', ylabel='electbyfuel_total'>
